# %% [markdown]
# <a href="https://colab.research.google.com/github/cmercadop/MetNumUN2023I/blob/main/Lab3/cmercadop_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My certificates

# %% [markdown]
# ![imagen_2023-03-04_193649906.png](data:image/png;base64,...)
